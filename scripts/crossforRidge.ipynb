# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
from proj1_helpers import *
from implementations import *
from costs import *
from process import *
from cross_validation import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
to_discard = ([[4,5,6,12,22,23,24,25,26,27,28,29],[4,5,6,12,22,26,27,28],[22], [22]])

# %%
from proj1_helpers import *
DATA_TRAIN_PATH = '../data/train.csv' # TODO: download train data and supply path here 
y, tX, ids = load_csv_data(DATA_TRAIN_PATH)

# %% [markdown]
# # Cross Validation to find Lambda with Ridge_regression

# %% [markdown]
# ## Jet 0

# %%
mask = (tX[:, 22] == 0)
x_tr = tX[mask]
y_tr = y[mask]
jet_num = 0
features = to_discard[jet_num]
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 5, stan =0)

# %%
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 6, stan =0)

# %%
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 7, stan =0)

# %% [markdown]
# ## Jet 1

# %%
mask = (tX[:, 22] == 1)
x_tr = tX[mask]
y_tr = y[mask]
jet_num = 1
features = to_discard[jet_num]
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 5, stan =0)

# %%
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 6, stan =0)

# %%
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 7, stan =0)

# %%
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 9, stan =0)

# %%
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 10, stan =0)

# %% [markdown]
# ## Jet 2

# %%
jet_num = 2
mask = (tX[:, 22] == jet_num )
x_tr = tX[mask]
y_tr = y[mask]
features = to_discard[jet_num]
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 6, stan =0)

# %%
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 7, stan =0)

# %%
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 8, stan =0)

# %%
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 9, stan =0)

# %% [markdown]
# ## Jet 3

# %%
jet_num = 3
mask = (tX[:, 22] == jet_num )
x_tr = tX[mask]
y_tr = y[mask]
features = to_discard[jet_num]
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 6, stan =0)

# %%
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 7, stan =0)

# %%
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 8, stan =0)

# %%
cross_validation_demo_ridge_regression_onACC(x_tr,y_tr, jet_num, features, degree = 9, stan =0)
